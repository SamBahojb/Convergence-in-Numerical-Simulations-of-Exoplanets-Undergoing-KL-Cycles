# %%
import matplotlib.pyplot as plt
import rebound
import numpy as np
import random 
import timeit
from scipy.optimize import curve_fit

# %%
def ias15_ts(timesteps):
    dE = []
    step = []
    time = []
    dL = []
    for t in timesteps:
        L0 = 0
        sim = rebound.Simulation()
        sim.integrator = "ias15"
        sim.ri_ias15.epsilon = 0.
        sim.dt = t
        tmax = 1.9e4
        step.append(t)
        
        sim.add(m=1.) #STAR
        sim.add(m=1.,a=1., omega = random.random()) #PLANET
        sim.add(m=1.,a=10.,inc=89.9, omega = random.random()) #PERTUBER
        
        #INITAL MEASUREMENTS 
        sim.move_to_com()
        E0 = sim.calculate_energy()
        L0_com = sim.calculate_angular_momentum()
        
        L0_temp = 0 
        for i in range(len(L0_com)):
            L0_temp += (L0_com[i])**2
        L0 = (np.sqrt(L0_temp))
        
        #INTEGRATE
        t0 = timeit.default_timer()
        sim.integrate(tmax, exact_finish_time=0)
        tf = timeit.default_timer()
        time.append(tf-t0)
        
        #FINAL MEASUREMENTS
        dE.append(abs((sim.calculate_energy() - E0)/E0))
        
        LF = sim.calculate_angular_momentum()
        LF_temp = 0 
        for i in range(len(LF)):
            LF_temp += (LF[i])**2
        dL.append((abs(np.sqrt(LF_temp) - L0)/L0))
        
            
        #REMOVE SIM
        print("here")
        sim = 0
    return dE,step,time,dL

# %%
def whfast_ts(timesteps):
    dE = []
    step = []
    time = []
    dL = []
    for t in timesteps:
        L0 = 0
        sim = rebound.Simulation()
        sim.integrator = "whfast"
        sim.ri_whfast.corrector = 17
        sim.ri_whfast.safe_mode = 0
        sim.dt = t
        tmax = 1.9e4
        step.append(t)
        
        sim.add(m=1.) #STAR
        sim.add(m=1.,a=1., omega = random.random()) #PLANET
        sim.add(m=1.,a=10.,inc=89.9, omega = random.random()) #PERTUBER
        
        #INITAL MEASUREMENTS 
        sim.move_to_com()
        E0 = sim.calculate_energy()
        L0_com = sim.calculate_angular_momentum()
        
        L0_temp = 0 
        for i in range(len(L0_com)):
            L0_temp += (L0_com[i])**2
        L0 = (np.sqrt(L0_temp))
        
        #INTEGRATE
        t0 = timeit.default_timer()
        sim.integrate(tmax, exact_finish_time=0)
        tf = timeit.default_timer()
        time.append(tf-t0)
        
        #FINAL MEASUREMENTS
        dE.append(abs((sim.calculate_energy() - E0)/E0))
        
        LF = sim.calculate_angular_momentum()
        LF_temp = 0 
        for i in range(len(LF)):
            LF_temp += (LF[i])**2
        dL.append((abs(np.sqrt(LF_temp) - L0)/L0))
        
            
        #REMOVE SIM
        sim = 0
    return dE,step,time,dL

# %%
def leapfrog_ts(timesteps):
    dE = []
    step = []
    time = []
    dL = []
    for t in timesteps:
        L0 = 0 
        sim = rebound.Simulation()
        sim.integrator = "leapfrog"
        sim.dt = t
        tmax = 1.9e4
        step.append(t)
        
        sim.add(m=1.) #STAR
        sim.add(m=1.,a=1., omega = random.random()) #PLANET
        sim.add(m=1.,a=10.,inc=89.9, omega = random.random()) #PERTUBER
        
        #INITAL MEASUREMENTS 
        sim.move_to_com()
        E0 = sim.calculate_energy()
        L0_com = sim.calculate_angular_momentum()
        
        L0_temp = 0 
        for i in range(len(L0_com)):
            L0_temp += (L0_com[i])**2
        L0 = (np.sqrt(L0_temp))
        
        #INTEGRATE
        t0 = timeit.default_timer()
        sim.integrate(tmax, exact_finish_time=0)
        tf = timeit.default_timer()
        time.append(tf-t0)
        
        #FINAL MEASUREMENTS
        dE.append(abs((sim.calculate_energy() - E0)/E0))
        
        LF = sim.calculate_angular_momentum()
        LF_temp = 0 
        for i in range(len(LF)):
            LF_temp += (LF[i])**2
        dL.append((abs(np.sqrt(LF_temp) - L0)/L0))
            
        #REMOVE SIM
        sim = 0
    return dE,step,time,dL

# %%
def janus_ts(timesteps):
    dE = []
    step = []
    time = []
    dL = []
    for t in timesteps:
        L0 = 0 
        sim = rebound.Simulation()
        sim.integrator = "janus"
        sim.dt = t
        tmax = 1.9e4
        step.append(t)
        
        sim.add(m=1.) #STAR
        sim.add(m=1.,a=1., omega = random.random()) #PLANET
        sim.add(m=1.,a=10.,inc=89.9, omega = random.random()) #PERTUBER
        
        #INITAL MEASUREMENTS 
        sim.move_to_com()
        E0 = sim.calculate_energy()
        L0_com = sim.calculate_angular_momentum()
        
        L0_temp = 0 
        for i in range(len(L0_com)):
            L0_temp += (L0_com[i])**2
        L0 = (np.sqrt(L0_temp))
        
        #INTEGRATE
        t0 = timeit.default_timer()
        sim.integrate(tmax, exact_finish_time=0)
        tf = timeit.default_timer()
        time.append(tf-t0)
        
        #FINAL MEASUREMENTS
        dE.append(abs((sim.calculate_energy() - E0)/E0))
        
        LF = sim.calculate_angular_momentum()
        LF_temp = 0 
        for i in range(len(LF)):
            LF_temp += (LF[i])**2
        dL.append((abs(np.sqrt(LF_temp) - L0)/L0))
        
            
        #REMOVE SIM
        sim = 0
    return dE,step,time,dL

# %%
def saba_ts(timesteps):
    dE = []
    step = []
    time = []
    dL = []
    for t in timesteps:
        L0 = 0
        sim = rebound.Simulation()
        sim.integrator = "SABA(10,6,4)"
        sim.ri_saba.safe_mode = 0
        sim.dt = t
        tmax = 1.9e4
        step.append(t)
        
        sim.add(m=1.) #STAR
        sim.add(m=1.,a=1., omega = random.random()) #PLANET
        sim.add(m=1.,a=10.,inc=89.9, omega = random.random()) #PERTUBER
        
        #INITAL MEASUREMENTS 
        sim.move_to_com()
        E0 = sim.calculate_energy()
        L0_com = sim.calculate_angular_momentum()
        
        L0_temp = 0 
        for i in range(len(L0_com)):
            L0_temp += (L0_com[i])**2
        L0 = (np.sqrt(L0_temp))
        
        #INTEGRATE
        t0 = timeit.default_timer()
        sim.integrate(tmax, exact_finish_time=0)
        tf = timeit.default_timer()
        time.append(tf-t0)
        
        #FINAL MEASUREMENTS
        dE.append(abs((sim.calculate_energy() - E0)/E0))
        
        LF = sim.calculate_angular_momentum()
        LF_temp = 0 
        for i in range(len(LF)):
            LF_temp += (LF[i])**2
        dL.append((abs(np.sqrt(LF_temp) - L0)/L0))
        
            
        #REMOVE SIM
        sim = 0
    return dE,step,time,dL

# %%
def eos_ts(timesteps):
    dE = []
    step = []
    time = []
    dL = []
    for t in timesteps:
        L0 = 0 
        sim = rebound.Simulation()
        sim.integrator = "eos"
        sim.ri_eos.phi0 = "LF4"
        sim.ri_eos.phi1 = "LF4"
        sim.ri_eos.n = 2 
        sim.ri_eos.safe_mode = 0
        sim.dt = t
        tmax = 1.9e4
        step.append(t)
        
        sim.add(m=1.) #STAR
        sim.add(m=1.,a=1., omega = random.random()) #PLANET
        sim.add(m=1.,a=10.,inc=89.9, omega = random.random()) #PERTUBER
        
        #INITAL MEASUREMENTS 
        sim.move_to_com()
        E0 = sim.calculate_energy()
        L0_com = sim.calculate_angular_momentum()
        
        L0_temp = 0 
        for i in range(len(L0_com)):
            L0_temp += (L0_com[i])**2
        L0 = (np.sqrt(L0_temp))
        
        #INTEGRATE
        t0 = timeit.default_timer()
        sim.integrate(tmax, exact_finish_time=0)
        tf = timeit.default_timer()
        time.append(tf-t0)
        
        #FINAL MEASUREMENTS
        dE.append(abs((sim.calculate_energy() - E0)/E0))
        
        LF = sim.calculate_angular_momentum()
        LF_temp = 0 
        for i in range(len(LF)):
            LF_temp += (LF[i])**2
        dL.append((abs(np.sqrt(LF_temp) - L0)/L0))
        
            
        #REMOVE SIM
        sim = 0
    return dE,step,time,dL

# %%
dE1,s1,t1,dL1 = ias15_ts(np.logspace(-1,-3,50))
dE2,s2,t2,dL2 = whfast_ts(np.logspace(-1,-3,50))
dE3,s3,t3,dL3 = leapfrog_ts(np.logspace(-1,-3,50))
dE4,s4,t4,dL4 = janus_ts(np.logspace(-1,-3,50))
dE5,s5,t5,dL5 = saba_ts(np.logspace(-1,-3,50))
dE7,s7,t7,dL7 = eos_ts(np.logspace(-1,-3,50))

# %%
#PLOTS
plt.rcParams["font.size"] = 14
#plt.title("Timestep vs Relative Error in Energy for 1 KL Cycle")
plt.xscale("log")
plt.xlabel("Timestep")
plt.yscale("log")
plt.ylabel("Relative Error in Energy")
plt.plot(s1,dE1,"b", label = "IAS15")
plt.plot(s2,dE2,"g", label = "WHFAST")
plt.plot(s3,dE3,"c", label = "LEAPFROG")
plt.plot(s4,dE4,"m", label = "JANUS")
plt.plot(s5,dE5,"y", label = "SABA")
plt.plot(s7,dE7,"r", label = "EOS")
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
fig.set_dpi(100)
plt.legend()

# %%
plt.rcParams["font.size"] = 7
#plt.title("Timestep vs Relative Error in Angular Momentum for 1 KL Cycle")
plt.xscale("log")
plt.xlabel("Timestep")
plt.yscale("log")
plt.ylabel("Error in Energy")
plt.plot(s1,dL1,"b", label = "IAS15")
plt.plot(s2,dL2,"g", label = "WHFAST")
plt.plot(s3,dL3,"c", label = "LEAPFROG")
plt.plot(s4,dL4,"m", label = "JANUS")
plt.plot(s5,dL5,"y", label = "SABA")
plt.plot(s7,dL7,"r", label = "EOS")
plt.legend()

# %%
#PLOTS
plt.rcParams["font.size"] = 14
#plt.title("CPU Time vs Relative Error in Energy While Varing Timestep")
plt.xscale("log")
plt.xlabel("CPU Time")
plt.yscale("log")
plt.ylabel("Error in Energy")
plt.plot(t1,dE1,"b", label = "IAS15")
plt.plot(t2,dE2,"g", label = "WHFAST")
plt.plot(t3,dE3,"c", label = "LEAPFROG")
plt.plot(t4,dE4,"m", label = "JANUS")
plt.plot(t5,dE5,"y", label = "SABA")
plt.plot(t7,dE7,"r", label = "EOS")
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
fig.set_dpi(100)
plt.legend()

# %%
#PLOTS
plt.rcParams["font.size"] = 7
#plt.title("CPU Time vs Relative Error in Angular Momentum While Varing Timestep")
plt.xscale("log")
plt.xlabel("CPU Time")
plt.yscale("log")
plt.ylabel("Error in Angular Momentum")
plt.plot(t1,dL1,"b", label = "IAS15")
plt.plot(t2,dL2,"g", label = "WHFAST")
plt.plot(t3,dL3,"c", label = "LEAPFROG")
plt.plot(t4,dL4,"m", label = "JANUS")
plt.plot(t5,dL5,"y", label = "SABA")
plt.plot(t7,dL7,"r", label = "EOS")
plt.legend()
